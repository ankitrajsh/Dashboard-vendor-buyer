# %%
# Database Connection and Table Loading
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# Database connection parameters
pg_conn = psycopg2.connect(
    host="34.93.93.62",
    user="postgres",
    password="Y5mnshpDFF44",
    dbname="matomo_analytics",
    port="5432"
)

# Create SQLAlchemy engine for pandas integration
engine = create_engine("postgresql://postgres:Y5mnshpDFF44@34.93.93.62:5432/matomo_analytics")

print("Database connection successful!")

# List available tables
cursor = pg_conn.cursor()
cursor.execute("""
    SELECT table_name 
    FROM information_schema.tables 
    WHERE table_schema = 'public'
    ORDER BY table_name;
""")
tables = cursor.fetchall()
cursor.close()

print(f"\n Available tables ({len(tables)} found):")
for i, table in enumerate(tables, 1):
    print(f"{i:2d}. {table[0]}")



# Load main tables
logs = pd.read_sql("SELECT * FROM matomo_log_visit", engine)
link = pd.read_sql("SELECT * FROM matomo_log_link_visit_action", engine) 
action = pd.read_sql("SELECT * FROM matomo_log_action", engine)

print(f" Loaded matomo_log_visit: {len(logs)} rows, {len(logs.columns)} columns")
print(f" Loaded matomo_log_link_visit_action: {len(link)} rows, {len(link.columns)} columns")
print(f"Loaded matomo_log_action: {len(action)} rows, {len(action.columns)} columns")

# Close connections
pg_conn.close()
engine.dispose()
print("\n Database connections closed.")
# Out:
# Database connection successful!
#
#  Available tables (49 found):
#  1. matomo_access
#  2. matomo_archive_blob_2025_01
#  3. matomo_archive_blob_2025_02
#  4. matomo_archive_blob_2025_03
#  5. matomo_archive_blob_2025_04
#  6. matomo_archive_blob_2025_05
#  7. matomo_archive_blob_2025_06
#  8. matomo_archive_blob_2025_07
#  9. matomo_archive_blob_2025_08
# 10. matomo_archive_blob_2025_09
# 11. matomo_archive_invalidations
# 12. matomo_archive_numeric_2025_01
# 13. matomo_archive_numeric_2025_02
# 14. matomo_archive_numeric_2025_03
# 15. matomo_archive_numeric_2025_04
# 16. matomo_archive_numeric_2025_05
# 17. matomo_archive_numeric_2025_06
# 18. matomo_archive_numeric_2025_07
# 19. matomo_archive_numeric_2025_08
# 20. matomo_archive_numeric_2025_09
# 21. matomo_brute_force_log
# 22. matomo_changes
# 23. matomo_custom_dimensions
# 24. matomo_goal
# 25. matomo_locks
# 26. matomo_log_action
# 27. matomo_log_conversion
# 28. matomo_log_conversion_item
# 29. matomo_log_link_visit_action
# ...

# %%
import pandas as pd

# %%
logs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11366 entries, 0 to 11365
# Data columns (total 60 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   idvisit                      11366 non-null  int64
#  1   idsite                       11366 non-null  int64
#  2   idvisitor                    11366 non-null  object
#  3   visit_last_action_time       11366 non-null  datetime64[ns]
#  4   config_id                    11366 non-null  object
#  5   location_ip                  11366 non-null  object
#  6   profilable                   11366 non-null  int64
#  7   user_id                      0 non-null      object
#  8   visit_first_action_time      11366 non-null  datetime64[ns]
#  9   visit_goal_buyer             11366 non-null  int64
#  10  visit_goal_converted         11366 non-null  int64
#  11  visitor_returning            11366 non-null  int64
# ...

# %%
logs = logs[['idvisit', 'idsite', 'idvisitor', 'user_id']].copy()

# %%
logs.head()
# Out:
#    idvisit  idsite                                          idvisitor user_id
# 0        1       1  [b'\xf1', b'\xe0', b'\x8b', b'\xf8', b'\x0f', ...    None
# 1        2       1  [b'\x98', b'\xae', b'\x83', b'\x11', b'\x93', ...    None
# 2        3       2  [b'O', b'\x10', b'\x92', b'\xb4', b'\x90', b'\...    None
# 3        4       2  [b'*', b'\x9c', b'\x00', b'\x1c', b'\xf8', b'\...    None
# 4        5       2  [b'I', b'\x97', b'E', b'\x0b', b'<', b'7', b'f...    None

# %%
link.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275359 entries, 0 to 275358
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   idlink_va                     275359 non-null  int64
#  1   idsite                        275359 non-null  int64
#  2   idvisitor                     275359 non-null  object
#  3   idvisit                       275359 non-null  int64
#  4   idaction_url_ref              275359 non-null  int64
#  5   idaction_name_ref             275359 non-null  int64
#  6   custom_float                  0 non-null       object
#  7   pageview_position             275339 non-null  float64
#  8   server_time                   275359 non-null  datetime64[ns]
#  9   idpageview                    275359 non-null  object
#  10  idaction_name                 274886 non-null  float64
#  11  idaction_url                  275359 non-null  int64
# ...

# %%
main = link[['idsite','idvisitor','idvisit','idaction_name','idaction_url']].copy()

# %%
main.head()
# Out:
#    idsite                                          idvisitor  idvisit  \
# 0       1  [b'\x0b', b'\xef', b'\x8a', b')', b';', b'\x1f...     3261
# 1       1  [b'\xbb', b'=', b'\xc5', b'\xfd', b'\xd1', b'\...     3267
# 2       1  [b'\xbb', b'=', b'\xc5', b'\xfd', b'\xd1', b'\...     3267
# 3       1  [b'\xbb', b'=', b'\xc5', b'\xfd', b'\xd1', b'\...     3267
# 4       1  [b'&', b'\xa0', b'\x86', b'/', b'\xa6', b'\x05...     3260
#
#    idaction_name  idaction_url
# 0            1.0            32
# 1            1.0           185
# 2            1.0           187
# 3            1.0           185
# 4            1.0         13120

# %%
logs.head()
# Out:
#    idvisit  idsite                                          idvisitor user_id
# 0        1       1  [b'\xf1', b'\xe0', b'\x8b', b'\xf8', b'\x0f', ...    None
# 1        2       1  [b'\x98', b'\xae', b'\x83', b'\x11', b'\x93', ...    None
# 2        3       2  [b'O', b'\x10', b'\x92', b'\xb4', b'\x90', b'\...    None
# 3        4       2  [b'*', b'\x9c', b'\x00', b'\x1c', b'\xf8', b'\...    None
# 4        5       2  [b'I', b'\x97', b'E', b'\x0b', b'<', b'7', b'f...    None

# %%
logs.shape
# Out:
# (11366, 4)

# %%
# Count unique user_id values in logs dataframe
unique_user_ids = logs['user_id'].nunique()
print(f"Number of unique user IDs: {unique_user_ids}")
# Out:
# Number of unique user IDs: 0

# %%
link.head()
# Out:
#    idlink_va  idsite                                          idvisitor  \
# 0      97144       1  [b'\x0b', b'\xef', b'\x8a', b')', b';', b'\x1f...
# 1      97145       1  [b'\xbb', b'=', b'\xc5', b'\xfd', b'\xd1', b'\...
# 2      97146       1  [b'\xbb', b'=', b'\xc5', b'\xfd', b'\xd1', b'\...
# 3      97147       1  [b'\xbb', b'=', b'\xc5', b'\xfd', b'\xd1', b'\...
# 4      97148       1  [b'&', b'\xa0', b'\x86', b'/', b'\xa6', b'\x05...
#
#    idvisit  idaction_url_ref  idaction_name_ref custom_float  \
# 0     3261              3131                  1         None
# 1     3267               185                  1         None
# 2     3267               185                  1         None
# 3     3267               187                  1         None
# 4     3260             13120                  1         None
#
#    pageview_position         server_time idpageview  ...  time_network  \
# 0               28.0 2025-04-24 09:10:13     lujVT1  ...           0.0
# ...

# %%
# Convert server_time to datetime for proper analysis
link['server_time_360'] = pd.to_datetime(link['server_time'])

# Analyze all time-related columns in link dataframe
print("Time-related columns analysis in link dataframe:")
print("="*60)

# 1. Server time analysis
print("\n1. SERVER_TIME Analysis:")
print(f"   Data type: {link['server_time'].dtype}")
print(f"   Min date: {link['server_time'].min()}")
print(f"   Max date: {link['server_time'].max()}")
print(f"   Date range: {(pd.to_datetime(link['server_time'].max()) - pd.to_datetime(link['server_time'].min())).days} days")
print(f"   Unique timestamps: {link['server_time'].nunique()}")

# 2. Time performance columns analysis
time_columns = ['time_dom_completion', 'time_dom_processing', 'time_network', 
                'time_on_load', 'time_server', 'time_transfer']

print("\n2. TIME PERFORMANCE METRICS:")
for col in time_columns:
    if col in link.columns:
        print(f"\n   {col.upper()}:")
        print(f"     Non-null count: {link[col].count()}")
        if link[col].count() > 0:
            print(f"     Mean: {link[col].mean():.2f} ms")
            print(f"     Median: {link[col].median():.2f} ms")
            print(f"     Min: {link[col].min():.2f} ms")
            print(f"     Max: {link[col].max():.2f} ms")
            print(f"     Std: {link[col].std():.2f} ms")
        else:
            print(f"     No data available")

# 3. Time spent analysis
print("\n3. TIME_SPENT_REF_ACTION Analysis:")
print(f"   Non-null count: {link['time_spent_ref_action'].count()}")
if link['time_spent_ref_action'].count() > 0:
    print(f"   Mean time spent: {link['time_spent_ref_action'].mean():.2f} seconds")
    print(f"   Median time spent: {link['time_spent_ref_action'].median():.2f} seconds")
    print(f"   Min time spent: {link['time_spent_ref_action'].min()} seconds")
    print(f"   Max time spent: {link['time_spent_ref_action'].max()} seconds")
    print(f"   Std time spent: {link['time_spent_ref_action'].std():.2f} seconds")

# 4. Hourly distribution of server_time
print("\n4. HOURLY DISTRIBUTION:")
link['hour'] = pd.to_datetime(link['server_time']).dt.hour
hourly_dist = link['hour'].value_counts().sort_index()
print("   Hour | Count")
print("   -----|------")
for hour, count in hourly_dist.items():
    print(f"   {hour:2d}   | {count}")

# 5. Daily distribution 
print("\n5. DAILY DISTRIBUTION:")
daily_dist = link.groupby(link['server_time_360'].dt.date).size()
print("   Date       | Count")
print("   -----------|------")
for date, count in daily_dist.items():
    print(f"   {date} | {count}")

# 6. Performance metrics correlation
print("\n6. PERFORMANCE METRICS SUMMARY:")
perf_cols = [col for col in time_columns if col in link.columns and link[col].count() > 0]
if perf_cols:
    perf_data = link[perf_cols].describe()
    print(perf_data)
# Out:
# Time-related columns analysis in link dataframe:
# ...
#
# 1. SERVER_TIME Analysis:
#    Data type: datetime64[ns]
#    Min date: 2025-02-21 09:50:35
#    Max date: 2025-08-19 10:24:41
#    Date range: 179 days
#    Unique timestamps: 234346
#
# 2. TIME PERFORMANCE METRICS:
#
#    TIME_DOM_COMPLETION:
#      Non-null count: 27918
#      Mean: 5131.82 ms
#      Median: 2175.00 ms
#      Min: 52.00 ms
#      Max: 1020659.00 ms
#      Std: 15761.57 ms
#
#    TIME_DOM_PROCESSING:
#      Non-null count: 141291
#      Mean: 631.35 ms
#      Median: 48.00 ms
#      Min: 0.00 ms
#      Max: 74805.00 ms
#      Std: 1812.11 ms
#
#    TIME_NETWORK:
#      Non-null count: 141291
#      Mean: 101.24 ms
#      Median: 4.00 ms
#      Min: 0.00 ms
#      Max: 142021.00 ms
#      Std: 1191.03 ms
#
#    TIME_ON_LOAD:
#      Non-null count: 27098
#      Mean: 11.01 ms
#      Median: 1.00 ms
#      Min: 0.00 ms
#      Max: 3630.00 ms
#      Std: 61.17 ms
#
#    TIME_SERVER:
#      Non-null count: 141291
# ...

# %%
# Merge the dataframes to create a comprehensive dataset for session analysis
merged_data = logs.merge(link, on='idvisit', how='inner')

# Convert server_time to datetime if not already done
merged_data['server_time_dt'] = pd.to_datetime(merged_data['server_time'])

# Create session time analysis
session_analysis = merged_data.groupby('idvisit').agg({
    'server_time_dt': ['min', 'max', 'count'],
    'time_spent_ref_action': 'sum',
    'visit_total_time': 'first',
    'pageview_position': 'max'
}).reset_index()

# Flatten column names
session_analysis.columns = ['idvisit', 'session_start', 'session_end', 'total_pageviews', 
                           'total_time_spent_on_pages', 'visit_total_time', 'max_pageview_position']

# Calculate session duration in seconds
session_analysis['session_duration_seconds'] = (
    session_analysis['session_end'] - session_analysis['session_start']
).dt.total_seconds()

# Calculate session duration in minutes
session_analysis['session_duration_minutes'] = session_analysis['session_duration_seconds'] / 60

print("Session Time Analysis:")
print("=" * 50)
print(f"Total sessions: {len(session_analysis)}")
print(f"Average session duration: {session_analysis['session_duration_minutes'].mean():.2f} minutes")
print(f"Median session duration: {session_analysis['session_duration_minutes'].median():.2f} minutes")
print(f"Max session duration: {session_analysis['session_duration_minutes'].max():.2f} minutes")
print(f"Min session duration: {session_analysis['session_duration_minutes'].min():.2f} minutes")

print("\nSession Duration Distribution:")
print(session_analysis['session_duration_minutes'].describe())

# Display first few sessions
print("\nFirst 10 sessions:")
print(session_analysis.head(10))

# Add custom_dimension_1 to session analysis
session_analysis = session_analysis.merge(
    logs[['idvisit', 'custom_dimension_1']], 
    on='idvisit', 
    how='left'
)

print("\nCustom Dimension 1 Analysis:")
print("=" * 50)
print(f"Sessions with custom_dimension_1: {session_analysis['custom_dimension_1'].notna().sum()}")
print(f"Sessions without custom_dimension_1: {session_analysis['custom_dimension_1'].isna().sum()}")
print("\nCustom Dimension 1 Distribution:")
print(session_analysis['custom_dimension_1'].value_counts(dropna=False))

# Add URL analysis to session analysis by merging with action data
session_urls = merged_data.merge(
    action[['idaction_url', 'full_url']], 
    left_on='idaction_url', 
    right_on='idaction_url', 
    how='left'
)

# Group URLs by session
session_url_analysis = session_urls.groupby('idvisit').agg({
    'full_url': lambda x: list(x.dropna().unique()),
    'pageview_position': 'count'
}).reset_index()

session_url_analysis.columns = ['idvisit', 'urls_visited', 'total_url_visits']

# Merge with existing session analysis
session_analysis = session_analysis.merge(session_url_analysis, on='idvisit', how='left')

print("\nURL Analysis per Session:")
print("=" * 50)
print(f"Sessions with URL data: {session_analysis['urls_visited'].notna().sum()}")
print(f"Average URLs per session: {session_analysis['total_url_visits'].mean():.2f}")
print(f"Max URLs in a session: {session_analysis['total_url_visits'].max()}")

print("\nSample sessions with URLs:")
for i, row in session_analysis.head(10).iterrows():
    print(f"\nSession {row['idvisit']} (Duration: {row['session_duration_minutes']:.1f} min):")
    if pd.notna(row['urls_visited']) and row['urls_visited']:
        for j, url in enumerate(row['urls_visited'][:5], 1):  # Show first 5 URLs
            print(f"  {j}. {url}")
        if len(row['urls_visited']) > 5:
            print(f"  ... and {len(row['urls_visited']) - 5} more URLs")
    else:
        print("  No URL data available")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 8
#       5 merged_data['server_time_dt'] = pd.to_datetime(merged_data['server_time'])
#       7 # Create session time analysis
# ----> 8 session_analysis = merged_data.groupby('idvisit').agg({
#       9     'server_time_dt': ['min', 'max', 'count'],
#      10     'time_spent_ref_action': 'sum',
#      11     'visit_total_time': 'first',
#      12     'pageview_position': 'max'
#      13 }).reset_index()
#      15 # Flatten column names
#      16 session_analysis.columns = ['idvisit', 'session_start', 'session_end', 'total_pageviews',
#      17                            'total_time_spent_on_pages', 'visit_total_time', 'max_pageview_position']
#
# ...

# %%
link["server_time"].min()
# Out:
# '2025-02-21 09:50:35'

# %%
link["server_time"].max()
# Out:
# '2025-04-30 09:53:54'

# %%
link["server_time"].unique().shape
# Out:
# (959,)

# %%
#create 360 dataset for server_time
# Group by date from server_time_360
link_grouped = link.groupby(link['server_time_360'].dt.date).size()
print("Daily visit counts:")
print(link_grouped)
# Out:
# Daily visit counts:
# server_time_360
# 2025-02-21     18
# 2025-02-24    376
# 2025-02-25    215
# 2025-02-26      8
# 2025-02-27    381
# 2025-04-30      2
# dtype: int64

# %%
action.head()
# Out:
#    idaction                                               name        hash  \
# 0         1  Vipani | Smart Procurement Platform for the Di...  1313366454
# 1         2  localhost/rfq/buyer/generate-po?quoteId=1127&r...  3909166454
# 2         3                     localhost/rfq/sellers/rfq-list  2509562998
# 3         4                         localhost/order-management  3743773319
# 4         5                                     192.168.9.133/   876754619
#
#    type  url_prefix
# 0     4         NaN
# 1     1         0.0
# 2     1         0.0
# 3     1         0.0
# 4     1         0.0

# %%
#ADD These according the type of URL prefixes in log_action table
# Create URL mapping in log_action
url_prefix_map = {
    0.0: 'http://',  # No prefix
    1.0: 'http://www.',
    2.0: 'https://',
    3.0: 'https://www.'
}

# Apply the mapping to create a new column with the actual prefix
action['url_prefix_text'] = action['url_prefix'].map(url_prefix_map)

# %%
action.head()
# Out:
#    idaction                                               name        hash  \
# 0         1  Vipani | Smart Procurement Platform for the Di...  1313366454
# 1         2  localhost/rfq/buyer/generate-po?quoteId=1127&r...  3909166454
# 2         3                     localhost/rfq/sellers/rfq-list  2509562998
# 3         4                         localhost/order-management  3743773319
# 4         5                                     192.168.9.133/   876754619
#
#    type  url_prefix url_prefix_text
# 0     4         NaN             NaN
# 1     1         0.0         http://
# 2     1         0.0         http://
# 3     1         0.0         http://
# 4     1         0.0         http://

# %%
#add name after the url_prefix_map to make proper url
action['full_url'] = action['url_prefix_text'] + action['name']

# %%
action.head()
# Out:
#    idaction                                               name        hash  \
# 0         1  Vipani | Smart Procurement Platform for the Di...  1313366454
# 1         2  localhost/rfq/buyer/generate-po?quoteId=1127&r...  3909166454
# 2         3                     localhost/rfq/sellers/rfq-list  2509562998
# 3         4                         localhost/order-management  3743773319
# 4         5                                     192.168.9.133/   876754619
#
#    type  url_prefix
# 0     4         NaN
# 1     1         0.0
# 2     1         0.0
# 3     1         0.0
# 4     1         0.0

# %%
# # Count total features (URL segments) before the first slash in the path
# action['features_before_first_slash'] = action['full_url'].str.replace(r'^https?://[^/]+/', '', regex=True).str.split('/').str[0].str.len()
# # Count occurrences of specific domains in full_url
# localhost_count = action['full_url'].str.contains('localhost', na=False).sum()
# ip_count = action['full_url'].str.contains('192.168.9.133', na=False).sum()
# # Count occurrences of devpy.vipani.ai domain in full_url
# devpy_count = action['full_url'].str.contains('devpy.vipani.ai', na=False).sum()
# print(f"Number of localhost URLs: {localhost_count}")
# print(f"Number of devpy.vipani.ai URLs: {devpy_count}")
# print(f"Number of 192.168.9.133 URLs: {ip_count}")

# %%
# !pip install networkx matplotlib

# %%
import re

# Create a tree structure showing URL paths after each slash count

def create_url_tree():
    # Filter out NaN values and extract the path after domain
    valid_urls = action.dropna(subset=['full_url'])
    
    url_tree = {}
    
    for url in valid_urls['full_url']:
        # Remove protocol and domain to get the path
        path_match = re.match(r'https?://[^/]+(/.*)?', url)
        if path_match and path_match.group(1):
            path = path_match.group(1)
            # Split by slash and remove empty strings
            segments = [seg for seg in path.split('/') if seg]
            
            # Build tree structure
            current_level = url_tree
            for i, segment in enumerate(segments):
                if segment not in current_level:
                    current_level[segment] = {}
                current_level = current_level[segment]
    
    return url_tree

# Function to print tree structure
def print_tree(tree, level=0, max_level=3):
    if level > max_level:
        return
    # Count segments at current level before last slash
    segment_count = len(tree)
    if level == 0:
        print(f"Total URL segments: {segment_count}")
    segment_count = len(tree)
    if level == 0:
        print(f"Total URL segments: {segment_count}")
    for key, subtree in sorted(tree.items()):
        print("  " * level + f"├── {key}")
        if isinstance(subtree, dict) and subtree:
            print_tree(subtree, level + 1, max_level)
# Create and display the URL tree
url_tree = create_url_tree()
print("URL Path Tree Structure:")
print_tree(url_tree)

print("Slash Count Distribution:")
print(action['slash_count'].value_counts().sort_index())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1242606/1704450197.py in ?()
#      40         print("  " * level + f"├── {key}")
#      41         if isinstance(subtree, dict) and subtree:
#      42             print_tree(subtree, level + 1, max_level)
#      43 # Create and display the URL tree
# ---> 44 url_tree = create_url_tree()
#      45 print("URL Path Tree Structure:")
#      46 print_tree(url_tree)
#      47
#
# /tmp/ipykernel_1242606/1704450197.py in ?()
#       5 def create_url_tree():
#       6     # Filter out NaN values and extract the path after domain
# ----> 7     valid_urls = action.dropna(subset=['full_url'])
#       8
#       9     url_tree = {}
#      10
#
# ~/miniconda3/envs/myenv/lib/python3.13/site-packages/pandas/core/frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
# ...

# %%
#how many unique in first level
def count_unique_first_level(tree):
    if not tree:
        return 0
    # Count unique keys at the first level
    return len(tree)

unique_count = count_unique_first_level(url_tree)
print(f"Unique URL segments at first level: {unique_count}")
#also print the all unique first level segments
print("Unique URL segments at first level:")
for key in sorted(url_tree.keys()):
    print(f"├── {key}")
# Out:
# Unique URL segments at first level: 12
# Unique URL segments at first level:
# ├── auction
# ├── auth
# ├── buyer-auction
# ├── calendar
# ├── deal-room
# ├── e-commerce
# ├── hub
# ├── onBoard
# ├── onboarding
# ├── order-management
# ├── prf
# ├── rfq

# %%
# Count unique segments at second level for each first level segment
def count_unique_second_level(tree):
    second_level_counts = {}
    total_unique_second_level = set()
    
    for first_key, first_subtree in tree.items():
        if isinstance(first_subtree, dict):
            second_level_count = len(first_subtree)
            second_level_counts[first_key] = second_level_count
            # Add all second level keys to the set for total unique count
            total_unique_second_level.update(first_subtree.keys())
    
    return second_level_counts, len(total_unique_second_level)

second_level_counts, total_unique_second = count_unique_second_level(url_tree)

print("Unique URL segments at second level for each first level:")
for first_key, count in sorted(second_level_counts.items()):
    print(f"├── {first_key}: {count} unique segments")
    
print(f"\nTotal unique segments at second level across all first level segments: {total_unique_second}")

# print("\nDetailed second level segments:")
# for first_key, first_subtree in sorted(url_tree.items()):
#     if isinstance(first_subtree, dict) and first_subtree:
#         print(f"\n├── {first_key}")
#         for second_key in sorted(first_subtree.keys()):
#             print(f"    ├── {second_key}")
# Out:
# Unique URL segments at second level for each first level:
# ├── auction: 7 unique segments
# ├── auth: 2 unique segments
# ├── buyer-auction: 5 unique segments
# ├── calendar: 0 unique segments
# ├── deal-room: 3 unique segments
# ├── e-commerce: 13 unique segments
# ├── hub: 6 unique segments
# ├── onBoard: 1 unique segments
# ├── onboarding: 3 unique segments
# ├── order-management: 176 unique segments
# ├── prf: 5 unique segments
# ├── rfq: 2 unique segments
#
# Total unique segments at second level across all first level segments: 222

# %%
# Count unique segments at third level for each second level segment
def count_unique_third_level(tree):
    third_level_counts = {}
    total_unique_third_level = set()
    
    for first_key, first_subtree in tree.items():
        if isinstance(first_subtree, dict):
            third_level_counts[first_key] = {}
            for second_key, second_subtree in first_subtree.items():
                if isinstance(second_subtree, dict):
                    third_level_count = len(second_subtree)
                    third_level_counts[first_key][second_key] = third_level_count
                    # Add all third level keys to the set for total unique count
                    total_unique_third_level.update(second_subtree.keys())
    
    return third_level_counts, len(total_unique_third_level)

third_level_counts, total_unique_third = count_unique_third_level(url_tree)

print("Unique URL segments at third level for each second level:")
for first_key, second_dict in sorted(third_level_counts.items()):
    print(f"\n├── {first_key}")
    for second_key, count in sorted(second_dict.items()):
        print(f"    ├── {second_key}: {count} unique segments")
    
print(f"\nTotal unique segments at third level across all segments: {total_unique_third}")
# Out:
# Unique URL segments at third level for each second level:
#
# ├── auction
#     ├── auction-details: 0 unique segments
#     ├── bidder-req: 15 unique segments
#     ├── payment: 15 unique segments
#     ├── product-info: 16 unique segments
#     ├── seller-auction-details: 17 unique segments
#     ├── seller-auction-list: 0 unique segments
#     ├── seller-dashboard: 0 unique segments
#
# ├── auth
#     ├── login: 0 unique segments
#     ├── registration: 0 unique segments
#
# ├── buyer-auction
#     ├── buyer-auction-details: 12 unique segments
#     ├── buyer-auction-list: 0 unique segments
#     ├── buyer-dashboard: 0 unique segments
#     ├── buyer-product-details: 0 unique segments
#     ├── create-po: 0 unique segments
#
# ├── calendar
#
# ├── deal-room
#     ├── direct: 2 unique segments
#     ├── general: 1 unique segments
#     ├── rfq: 12 unique segments
#
# ├── e-commerce
#     ├── all-categories: 0 unique segments
#     ├── cart: 0 unique segments
# ...

# %%
# Count unique segments at fourth level for each third level segment
def count_unique_fourth_level(tree):
    fourth_level_counts = {}
    total_unique_fourth_level = set()
    
    for first_key, first_subtree in tree.items():
        if isinstance(first_subtree, dict):
            fourth_level_counts[first_key] = {}
            for second_key, second_subtree in first_subtree.items():
                if isinstance(second_subtree, dict):
                    fourth_level_counts[first_key][second_key] = {}
                    for third_key, third_subtree in second_subtree.items():
                        if isinstance(third_subtree, dict):
                            fourth_level_count = len(third_subtree)
                            fourth_level_counts[first_key][second_key][third_key] = fourth_level_count
                            # Add all fourth level keys to the set for total unique count
                            total_unique_fourth_level.update(third_subtree.keys())
    
    return fourth_level_counts, len(total_unique_fourth_level)

fourth_level_counts, total_unique_fourth = count_unique_fourth_level(url_tree)

# Only print segments that have higher number of fourth level segments (>5)
print("Unique URL segments at fourth level (showing only segments with >5 unique fourth level segments):")
for first_key, second_dict in sorted(fourth_level_counts.items()):
    first_level_printed = False
    for second_key, third_dict in sorted(second_dict.items()):
        second_level_printed = False
        for third_key, count in sorted(third_dict.items()):
            if count > 5:
                if not first_level_printed:
                    print(f"\n├── {first_key}")
                    first_level_printed = True
                if not second_level_printed:
                    print(f"    ├── {second_key}")
                    second_level_printed = True
                print(f"        ├── {third_key}: {count} unique segments")
    
print(f"\nTotal unique segments at fourth level across all segments: {total_unique_fourth}")
# Out:
# Unique URL segments at fourth level (showing only segments with >5 unique fourth level segments):
#
# ├── rfq
#     ├── buyer
#         ├── additional_rfq_details: 76 unique segments
#         ├── create_rfq: 13 unique segments
#         ├── rfq-details: 34 unique segments
#         ├── rfq-product-selection: 48 unique segments
#         ├── rfq-seller-selection: 39 unique segments
#     ├── sellers
#         ├── rfq-details: 38 unique segments
#
# Total unique segments at fourth level across all segments: 94

# %%
logs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 60 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   idvisit                      1000 non-null   int64
#  1   idsite                       1000 non-null   int64
#  2   idvisitor                    1000 non-null   object
#  3   visit_last_action_time       1000 non-null   object
#  4   config_id                    1000 non-null   object
#  5   location_ip                  1000 non-null   object
#  6   profilable                   1000 non-null   int64
#  7   user_id                      0 non-null      float64
#  8   visit_first_action_time      1000 non-null   object
#  9   visit_goal_buyer             1000 non-null   int64
#  10  visit_goal_converted         1000 non-null   int64
#  11  visitor_returning            1000 non-null   int64
#  12  visitor_seconds_since_first  1000 non-null   int64
# ...

# %%
link.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   idlink_va                     1000 non-null   int64
#  1   idsite                        1000 non-null   int64
#  2   idvisitor                     1000 non-null   object
#  3   idvisit                       1000 non-null   int64
#  4   idaction_url_ref              1000 non-null   int64
#  5   idaction_name_ref             1000 non-null   int64
#  6   custom_float                  0 non-null      float64
#  7   pageview_position             1000 non-null   int64
#  8   server_time                   1000 non-null   object
#  9   idpageview                    1000 non-null   object
#  10  idaction_name                 998 non-null    float64
#  11  idaction_url                  1000 non-null   int64
# ...

# %%
action.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   idaction    1000 non-null   int64
#  1   name        1000 non-null   object
#  2   hash        1000 non-null   int64
#  3   type        1000 non-null   int64
#  4   url_prefix  997 non-null    float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 39.2+ KB
